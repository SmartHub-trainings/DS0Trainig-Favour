# %% [markdown]
# # Plotting images

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# pixel:0(dull) and 255(brightest)
# rgb(red,green,blue)
# rgb(0,0,0):Black
# rgb(255,255,255):White
# rgb(255,0,0):red

# %%
# 1 chanel images : Gray scale or black and white
# 3 channel images: rgb

# %%
image1=np.random.randint(0,255,(10,10))

# %%
image1
# Out:
# array([[ 44,   7,  45,  52,  34,  11, 192, 226, 156,  83],
#        [109, 192,  40, 163, 169,  53, 195,  40,  16, 193],
#        [131,  33, 210, 105, 224, 220,  40, 219, 195,  12],
#        [178,   0, 116, 128,  39, 238, 227, 147,  50,  34],
#        [246, 203, 220,  97,  32, 158,  21, 254, 243, 227],
#        [129,  58,  12, 113,  77,  37, 239, 219,  14, 167],
#        [191,  80, 229, 230, 188, 186, 102, 187, 242,   5],
#        [134, 151,  52, 105, 210,  66, 187, 158, 203, 110],
#        [188, 251, 198,  62,  55,  57, 247, 132, 104, 180],
#        [220, 151, 147,  39, 140, 220, 215,  50, 195,  96]])

# %%
plt.imshow(image1)

# %%
plt.imshow(image1)
plt.axis('off');

# %%
image2=np.random.randint(0,255,(2,2,3))

# %%
image2
# Out:
# array([[[ 11,  40, 111],
#         [ 75,  72,   0]],
#
#        [[216,  61,  35],
#         [214, 151, 222]]])

# %%
image2=np.random.randint(0,255,(10,10,3))

# %%
image2
# Out:
# array([[[158, 101, 231],
#         [110,  39, 254],
#         [252, 111, 189],
#         [181,  19,   9],
#         [171, 160, 148],
#         [ 38, 220,   4],
#         [ 84,  26, 184],
#         [235, 149, 196],
#         [114, 150, 113],
#         [115, 111, 234]],
#
#        [[202, 237, 136],
#         [132, 140, 106],
#         [ 74,  30, 237],
#         [ 73, 203, 252],
#         [240, 210, 134],
#         [ 92,  56, 246],
#         [140, 162, 110],
#         [ 50, 171,  68],
#         [146,  56,   2],
#         [ 51, 101,  65]],
#
#        [[ 87, 211,  45],
#         [218, 235,  78],
#         [234, 198,  80],
#         [160, 193, 102],
#         [180,  90, 164],
#         [ 22, 180, 234],
#         [225, 252,  55],
#         [ 14, 185,  30],
#         [ 26,  12,  84],
#         [181,  55, 249]],
#
#        [[167,  18, 161],
#         [138,  75,  73],
#         [122, 237, 138],
#         [190, 233, 174],
#         [168,  74, 129],
#         [136,  78,  41],
# ...

# %%
plt.imshow(image2)
plt.axis("off");
plt.savefig("nft.png")

# %%
## Pillow(PIL) library
# pip install pillow

# %%
import PIL

# %%
img=PIL.Image.open("smartHub.png")

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=5140x4201 at 0x7FA3C64B58B0>

# %%
img.size
# Out:
# (5140, 4201)

# %%
img.mode
# Out:
# 'RGBA'

# %%
img_=np.array(img)

# %%
img_
# Out:
# array([[[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0]],
#
#        [[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0]],
#
#        [[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0]],
#
#        ...,
#
#        [[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0]],
#
#        [[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [255, 255, 255,   0],
# ...

# %%
img_.shape
# Out:
# (4201, 5140, 4)

# %%
img1=img_[:,:,:3]

# %%
img1
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
plt.imshow(img1)
plt.axis("off");

# %%
img1.shape
# Out:
# (4201, 5140, 3)

# %%
img2=(img1+np.random.randint(0,30,img1.shape))%255

# %%
plt.imshow(img2)
plt.axis("off");

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=5140x4201 at 0x7FA3C71A4670>

# %%
img.size
# Out:
# (5140, 4201)

# %%
img_re=img.resize((300,220))

# %%
img_re
# Out:
# <PIL.Image.Image image mode=RGBA size=300x220 at 0x7FA3C70DB7F0>

# %% [markdown]
# ## Custom styles

# %%
from matplotlib import style

# %%
style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
d=np.random.randint(1,20,20)

# %%
[str(i)*5 for i in range(1,21)]
# Out:
# ['11111',
#  '22222',
#  '33333',
#  '44444',
#  '55555',
#  '66666',
#  '77777',
#  '88888',
#  '99999',
#  '1010101010',
#  '1111111111',
#  '1212121212',
#  '1313131313',
#  '1414141414',
#  '1515151515',
#  '1616161616',
#  '1717171717',
#  '1818181818',
#  '1919191919',
#  '2020202020']

# %%
plt.bar([str(i)*5 for i in range(1,21)],d)
# Out:
# <BarContainer object of 20 artists>

# %%
plt.bar([str(i)*5 for i in range(1,21)],d)
plt.xticks(rotation=90);

# %%
plt.barh([str(i)*5 for i in range(1,21)],d)
# plt.xticks();
# Out:
# <BarContainer object of 20 artists>

# %%
plt.stem([str(i)*5 for i in range(1,21)],d)
plt.xticks(rotation=90);

# %%
plt.step([str(i)*5 for i in range(1,21)],d)
plt.xticks(rotation=90);

# %%
style.use("tableau-colorblind10")

# %%
plt.bar([str(i)*5 for i in range(1,21)],d)
plt.xticks(rotation=90);

# %%
plt.step([str(i)*5 for i in range(1,21)],d)
plt.xticks(rotation=90);

# %%
# style.use("")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_22353/3172047966.py in <module>
# ----> 1 style.use()
#
# TypeError: use() missing 1 required positional argument: 'style'

# %%
plt.step([str(i)*5 for i in range(1,21)],d)
plt.xticks(rotation=90);

# %%
## contour plots
## 3d plots
