# %%
import pandas as pd
import numpy as np

# %%
s1=pd.Series([3,4,56,7,65,5,7,78,7])

# %%
s1
# Out:
# 0     3
# 1     4
# 2    56
# 3     7
# 4    65
# 5     5
# 6     7
# 7    78
# 8     7
# dtype: int64

# %%
s1.plot()
# Out:
# <AxesSubplot:>

# %%
s1.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
s1.plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='None'>

# %%
s1.plot(kind="bar")

# %%
s1
# Out:
# 0     3
# 1     4
# 2    56
# 3     7
# 4    65
# 5     5
# 6     7
# 7    78
# 8     7
# dtype: int64

# %%
s1.index=range(1,10)

# %%
s1
# Out:
# 1     3
# 2     4
# 3    56
# 4     7
# 5    65
# 6     5
# 7     7
# 8    78
# 9     7
# dtype: int64

# %%
s1[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_23481/643609873.py in <module>
# ----> 1 s1[0]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ...

# %%
s1[1]
# Out:
# 3

# %% [markdown]
# ## Implicit and explit indexing

# %%
s1.iloc[0]
# Out:
# 3

# %%
s1.iloc[1]
# Out:
# 4

# %%
s1.loc[1]
# Out:
# 3

# %%
s1+7
# Out:
# 1    10
# 2    11
# 3    63
# 4    14
# 5    72
# 6    12
# 7    14
# 8    85
# 9    14
# dtype: int64

# %%
s1.sum()
# Out:
# 232

# %%
s1.mean()
# Out:
# 25.77777777777778

# %%
s1.std()
# Out:
# 30.946638661483806

# %%
df=pd.DataFrame(np.linspace(10,50).reshape(10,-1).round())

# %%
df
# Out:
#       0     1     2     3     4
# 0  10.0  11.0  12.0  12.0  13.0
# 1  14.0  15.0  16.0  17.0  17.0
# 2  18.0  19.0  20.0  21.0  21.0
# 3  22.0  23.0  24.0  25.0  26.0
# 4  26.0  27.0  28.0  29.0  30.0
# 5  30.0  31.0  32.0  33.0  34.0
# 6  34.0  35.0  36.0  37.0  38.0
# 7  39.0  39.0  40.0  41.0  42.0
# 8  43.0  43.0  44.0  45.0  46.0
# 9  47.0  48.0  48.0  49.0  50.0

# %%
df.columns=list("abcde")

# %%
df
# Out:
#       a     b     c     d     e
# 0  10.0  11.0  12.0  12.0  13.0
# 1  14.0  15.0  16.0  17.0  17.0
# 2  18.0  19.0  20.0  21.0  21.0
# 3  22.0  23.0  24.0  25.0  26.0
# 4  26.0  27.0  28.0  29.0  30.0
# 5  30.0  31.0  32.0  33.0  34.0
# 6  34.0  35.0  36.0  37.0  38.0
# 7  39.0  39.0  40.0  41.0  42.0
# 8  43.0  43.0  44.0  45.0  46.0
# 9  47.0  48.0  48.0  49.0  50.0

# %%
f=df.columns.array

# %%
f[3]="Smart"

# %%
df.columns=f

# %%
df
# Out:
#       a     b     c  Smart     e
# 0  10.0  11.0  12.0   12.0  13.0
# 1  14.0  15.0  16.0   17.0  17.0
# 2  18.0  19.0  20.0   21.0  21.0
# 3  22.0  23.0  24.0   25.0  26.0
# 4  26.0  27.0  28.0   29.0  30.0
# 5  30.0  31.0  32.0   33.0  34.0
# 6  34.0  35.0  36.0   37.0  38.0
# 7  39.0  39.0  40.0   41.0  42.0
# 8  43.0  43.0  44.0   45.0  46.0
# 9  47.0  48.0  48.0   49.0  50.0

# %%
df["Favour"]=df["c"]

# %%
df
# Out:
#       a     b     c  Smart     e  Favour
# 0  10.0  11.0  12.0   12.0  13.0    12.0
# 1  14.0  15.0  16.0   17.0  17.0    16.0
# 2  18.0  19.0  20.0   21.0  21.0    20.0
# 3  22.0  23.0  24.0   25.0  26.0    24.0
# 4  26.0  27.0  28.0   29.0  30.0    28.0
# 5  30.0  31.0  32.0   33.0  34.0    32.0
# 6  34.0  35.0  36.0   37.0  38.0    36.0
# 7  39.0  39.0  40.0   41.0  42.0    40.0
# 8  43.0  43.0  44.0   45.0  46.0    44.0
# 9  47.0  48.0  48.0   49.0  50.0    48.0

# %%
df.drop(columns=["c"],inplace=True)

# %%
df
# Out:
#       a     b  Smart     e  Favour
# 0  10.0  11.0   12.0  13.0    12.0
# 1  14.0  15.0   17.0  17.0    16.0
# 2  18.0  19.0   21.0  21.0    20.0
# 3  22.0  23.0   25.0  26.0    24.0
# 4  26.0  27.0   29.0  30.0    28.0
# 5  30.0  31.0   33.0  34.0    32.0
# 6  34.0  35.0   37.0  38.0    36.0
# 7  39.0  39.0   41.0  42.0    40.0
# 8  43.0  43.0   45.0  46.0    44.0
# 9  47.0  48.0   49.0  50.0    48.0

# %%
df["Favour"]
# Out:
# 0    12.0
# 1    16.0
# 2    20.0
# 3    24.0
# 4    28.0
# 5    32.0
# 6    36.0
# 7    40.0
# 8    44.0
# 9    48.0
# Name: Favour, dtype: float64

# %%
df.Favour
# Out:
# 0    12.0
# 1    16.0
# 2    20.0
# 3    24.0
# 4    28.0
# 5    32.0
# 6    36.0
# 7    40.0
# 8    44.0
# 9    48.0
# Name: Favour, dtype: float64

# %%
df.Smart
# Out:
# 0    12.0
# 1    17.0
# 2    21.0
# 3    25.0
# 4    29.0
# 5    33.0
# 6    37.0
# 7    41.0
# 8    45.0
# 9    49.0
# Name: Smart, dtype: float64
