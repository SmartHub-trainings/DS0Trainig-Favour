# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame({"A":[1,2,3],"B":[4,3,6]},index=list("123"))

# %%
df
# Out:
#    A  B
# 1  1  4
# 2  2  3
# 3  3  6

# %%
df2=pd.DataFrame({"A":np.random.randint(1,4,3),
                  "B":np.random.randint(1,4,3)},
                 index=list("123"))

# %%
df2
# Out:
#    A  B
# 1  3  3
# 2  1  2
# 3  1  2

# %%
df_combined=df.append(df2)

# %%
df3=pd.DataFrame(np.random.randint(12,20,(3,2)))

# %%
df3
# Out:
#     0   1
# 0  15  15
# 1  17  18
# 2  14  19

# %%
df.append(df3)
# Out:
#      A    B     0     1
# 1  1.0  4.0   NaN   NaN
# 2  2.0  3.0   NaN   NaN
# 3  3.0  6.0   NaN   NaN
# 0  NaN  NaN  15.0  15.0
# 1  NaN  NaN  17.0  18.0
# 2  NaN  NaN  14.0  19.0

# %%
df_combined
# Out:
#    A  B
# 1  1  4
# 2  2  3
# 3  3  6
# 1  3  3
# 2  1  2
# 3  1  2

# %%
df_combined[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df_combined.loc[1,:]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# ...

# %%
df_combined.iloc[1]
# Out:
# A    2
# B    3
# Name: 2, dtype: int64

# %%
df.append(df2,ignore_index=True)
# Out:
#    A  B
# 0  1  4
# 1  2  3
# 2  3  6
# 3  3  3
# 4  1  2
# 5  1  2

# %%
pd.concat([df,df2])
# Out:
#    A  B
# 1  1  4
# 2  2  3
# 3  3  6
# 1  3  3
# 2  1  2
# 3  1  2

# %%
pd.concat([df,df3])
# Out:
#      A    B     0     1
# 1  1.0  4.0   NaN   NaN
# 2  2.0  3.0   NaN   NaN
# 3  3.0  6.0   NaN   NaN
# 0  NaN  NaN  15.0  15.0
# 1  NaN  NaN  17.0  18.0
# 2  NaN  NaN  14.0  19.0

# %%
pd.concat([df,df2],axis=1)
# Out:
#    A  B  A  B
# 1  1  4  3  3
# 2  2  3  1  2
# 3  3  6  1  2

# %%
pd.concat([df,df2],axis=0,keys=["key 1","key 2"])
# Out:
#          A  B
# key 1 1  1  4
#       2  2  3
#       3  3  6
# key 2 1  3  3
#       2  1  2
#       3  1  2

# %%
meds=pd.read_csv("../../../datasets/human-acetylcholinesterase-dataset-from-chembl/AChE_Bioactivity_data_1.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_61625/807513469.py in <module>
# ----> 1 meds=pd.read_csv("../../../../datasets/human-acetylcholinesterase-dataset-from-chembl/AChE_Bioactivity_data_1.csv")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
pd.read_csv("../../../datasets/human-acetylcholinesterase-dataset-from-chembl/AChE_Bioactivity_data_1.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_61625/749350556.py in <module>
# ----> 1 pd.read_csv("../../../datasets/human-acetylcholinesterase-dataset-from-chembl/AChE_Bioactivity_data_1.csv")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
meds=pd.read_csv(r"/Users/georgebsmith/Desktop/main/datasets/human-acetylcholinesterase-dataset-from-chembl/AChE_Bioactivity_data_1.csv")

# %%
meds
# Out:
#       activity_comment  activity_id  \
# 0                  NaN        33969
# 1                  NaN        37563
# 2                  NaN        37565
# 3                  NaN        38902
# 4                  NaN        41170
# ...                ...          ...
# 15537              NaN     23106319
# 15538              NaN     23107435
# 15539              NaN     23107519
# 15540       Not Active     23118491
# 15541       Not Active     23119783
#
#                                      activity_properties assay_chembl_id  \
# 0                                                     []    CHEMBL643384
# 1                                                     []    CHEMBL643384
# 2                                                     []    CHEMBL643384
# 3                                                     []    CHEMBL643384
# 4                                                     []    CHEMBL643384
# ...                                                  ...             ...
# ...

# %%
meds.head()
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0              NaN        33969                  []    CHEMBL643384
# 1              NaN        37563                  []    CHEMBL643384
# 2              NaN        37565                  []    CHEMBL643384
# 3              NaN        38902                  []    CHEMBL643384
# 4              NaN        41170                  []    CHEMBL643384
#
#                                    assay_description assay_type  \
# 0  Inhibitory concentration against acetylcholine...          B
# 1  Inhibitory concentration against acetylcholine...          B
# 2  Inhibitory concentration against acetylcholine...          B
# 3  Inhibitory concentration against acetylcholine...          B
# 4  Inhibitory concentration against acetylcholine...          B
#
#    assay_variant_accession  assay_variant_mutation bao_endpoint   bao_format  \
# 0                      NaN                     NaN  BAO_0000190  BAO_0000357
# ...

# %%
# pd.set_option(display="max-columns")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_61625/4079364872.py in <module>
# ----> 1 pd.set_option(display="max-columns")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_config/config.py in __call__(self, *args, **kwds)
#     241
#     242     def __call__(self, *args, **kwds):
# --> 243         return self.__func__(*args, **kwds)
#     244
#     245     @property
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_config/config.py in _set_option(*args, **kwargs)
#     124     nargs = len(args)
#     125     if not nargs or nargs % 2 != 0:
# --> 126         raise ValueError("Must provide an even number of non-keyword arguments")
#     127
#     128     # default to false
#
# ValueError: Must provide an even number of non-keyword arguments

# %%
meds.bao_endpoint
# Out:
# 0        BAO_0000190
# 1        BAO_0000190
# 2        BAO_0000190
# 3        BAO_0000190
# 4        BAO_0000190
#             ...
# 15537    BAO_0000179
# 15538    BAO_0000179
# 15539    BAO_0000179
# 15540    BAO_0000179
# 15541    BAO_0000179
# Name: bao_endpoint, Length: 15542, dtype: object

# %%
meds.bao_endpoint.apply(lambda x: x.split("_")[0]).value_counts()
# Out:
# BAO    15542
# Name: bao_endpoint, dtype: int64

# %%
meds.bao_endpoint.apply(lambda x: x.split("_")[1]).value_counts()
# Out:
# 0000190    7549
# 0000179    2754
# 0000192    1827
# 0000201    1044
# 0001103     824
# 0000376     623
# 0000375     360
# 0000034     242
# 0000181      86
# 0002146      57
# 0000188      51
# 0002809      37
# 0000599      24
# 0000199      19
# 0000477      15
# 0000586      14
# 0000193       9
# 0002115       5
# 0000581       2
# Name: bao_endpoint, dtype: int64
